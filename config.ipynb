# %%
dbutils.widgets.text("catalog", "workspace")
dbutils.widgets.text("schema", "default")
dbutils.widgets.text("base_volume_path", "/Volumes/workspace/default/lakehouse")

# %%
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
base_path = dbutils.widgets.get("base_volume_path")

# %%
landing_path = f"{base_path}/landing/sales"
 
bronze_table = f"{catalog}.{schema}.sales_bronze"
silver_table = f"{catalog}.{schema}.sales_silver"
gold_table = f"{catalog}.{schema}.sales_gold"
